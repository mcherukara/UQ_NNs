# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.utils.data import TensorDataset, DataLoader

from tqdm import tqdm 
import numpy as np
#from skimage.transform import resize
from numpy.fft import fftn, fftshift

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
#from sklearn.utils import shuffle
#from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('font',family='Times New Roman')
matplotlib.rcParams['font.size'] = 20

# %%
EPOCHS = 200
NGPUS = torch.cuda.device_count()
BATCH_SIZE = max(NGPUS,1) * 32
LR = NGPUS * 1e-3
print("GPUs:", NGPUS, "Batch size:", BATCH_SIZE, "Learning rate:", LR)
# Out:
# GPUs: 1 Batch size: 32 Learning rate: 0.001

# %% [markdown]
# ### Generate clean and noisy data from a sin()

# %%
x_train = torch.cat([torch.linspace(-10,-5,250), torch.linspace(0,5,250)]) #Create tensor here and you're good
y_train  = torch.sin(x_train)
noise = np.concatenate([np.zeros(250),np.random.random(x_train[250:].shape)-0.5])
y_train += noise
plt.plot(x_train,y_train,'C3o')
plt.title("Training data")
# Out:
# Text(0.5, 1.0, 'Training data')

# %%
x_test = torch.linspace(-10,10,500) #Create tensor here and you're good
y_test  = torch.sin(x_test)
noise = np.concatenate([np.zeros(250),np.random.random(x_test[250:].shape)-0.5])
y_test += noise
plt.plot(x_test,y_test,'C3o')
plt.title("Test data")
# Out:
# Text(0.5, 1.0, 'Test data')

# %%
#Create a TensorDataset and batched loader
train_data = TensorDataset(x_train,y_train)
test_data = TensorDataset(x_test)
N_TRAIN = x_train.shape[0]
N_VALID = 100

train_data2, valid_data = torch.utils.data.random_split(train_data,[N_TRAIN-N_VALID,N_VALID])
print("Train, valid and test", len(train_data2),len(valid_data),len(test_data))

#download and load training data
trainloader = DataLoader(train_data2, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

validloader = DataLoader(valid_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

#same for test
#download and load training data
testloader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# Train, valid and test 400 100 500

# %%
class noisy_model(nn.Module):
    def __init__(self):
        super(noisy_model, self).__init__()
        self.D_in = 1 #Input dimension
        self.D_out = 1 #Output dimension
        self.H = [50,100,150] #Number of neurons in hidden layers

        self.fc = nn.Sequential(
            nn.Linear(self.D_in, self.H[0]), #Input 
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(self.H[0], self.H[1]),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(self.H[1], self.H[2]),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(self.H[2],self.D_out)
        )
    def forward(self,x):
        return self.fc(x)

# %% [markdown]
# ### Print model summary and move to GPU if available

# %%
model = noisy_model()
summary(model,(1,1),device="cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 50]             100
#               ReLU-2                [-1, 1, 50]               0
#            Dropout-3                [-1, 1, 50]               0
#             Linear-4               [-1, 1, 100]           5,100
#               ReLU-5               [-1, 1, 100]               0
#            Dropout-6               [-1, 1, 100]               0
#             Linear-7               [-1, 1, 150]          15,150
#               ReLU-8               [-1, 1, 150]               0
#            Dropout-9               [-1, 1, 150]               0
#            Linear-10                 [-1, 1, 1]             151
# ================================================================
# Total params: 20,501
# Trainable params: 20,501
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------

# %%
for x,y in trainloader:
    x = x.to(device)
    y = y.to(device)
    y_pred = model(x.unsqueeze(-1))
    print("Trainloader", x.shape,y.shape,y_pred.shape)
    break

for x,y in validloader:
    x = x.to(device)
    y = y.to(device)
    y_pred = model(x.unsqueeze(-1))
    print("Validloader", x.shape,y.shape,y_pred.shape)
    break
# Out:
# Trainloader torch.Size([32]) torch.Size([32]) torch.Size([32, 1])
# Validloader torch.Size([32]) torch.Size([32]) torch.Size([32, 1])

# %%
#Optimization details
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr = LR)

# %%
def train(trainloader, metrics):
    tot_loss = 0.0
    for i , (x, y) in enumerate(trainloader):
        x = x.to(device) #Move data to approp device
        y = y.to(device)

        y_pred = model(x.unsqueeze(-1)) #Forward pass

        loss = criterion (y_pred.squeeze(), y) #Compute loss
        tot_loss += loss.detach().item()

        #Zero current grads and do backprop
        optimizer.zero_grad() 
        loss.backward()
        optimizer.step()
        
    #Divide cumulative loss by number of batches-- sli inaccurate because last batch is different size
    metrics['losses'].append([tot_loss/i]) 


def validate(validloader, metrics):
    tot_loss = 0.0
    for j , (x, y) in enumerate(validloader):
        x = x.to(device) #Move data to approp device
        y = y.to(device)

        y_pred = model(x.unsqueeze(-1)) #Forward pass

        loss = criterion (y_pred.squeeze(), y) #Compute loss
        tot_loss += loss.detach().item()
        
    metrics['val_losses'].append([tot_loss/j])

# %%
metrics = {'losses':[],'val_losses':[]}#, 'lrs':[], 'best_val_loss' : np.inf}
for epoch in range (EPOCHS):
    
  #Set model to train mode
  model.train() 
    
  #Training loop
  train(trainloader,metrics)

    
  #Switch model to eval mode
  model.eval()
    
  #Validation loop
  validate(validloader,metrics)
  
  print('Epoch: %d | Train Loss: %.5f | Val Loss: %.5f' %(epoch, metrics['losses'][-1][0], metrics['val_losses'][-1][0]))
# Out:
# Epoch: 0 | Train Loss: 0.67347 | Val Loss: 0.71937
# Epoch: 1 | Train Loss: 0.62969 | Val Loss: 0.74250
# Epoch: 2 | Train Loss: 0.60055 | Val Loss: 0.64870
# Epoch: 3 | Train Loss: 0.55943 | Val Loss: 0.53288
# Epoch: 4 | Train Loss: 0.57290 | Val Loss: 0.65128
# Epoch: 5 | Train Loss: 0.54874 | Val Loss: 0.55103
# Epoch: 6 | Train Loss: 0.55438 | Val Loss: 0.59823
# Epoch: 7 | Train Loss: 0.56257 | Val Loss: 0.48687
# Epoch: 8 | Train Loss: 0.53244 | Val Loss: 0.49406
# Epoch: 9 | Train Loss: 0.52556 | Val Loss: 0.58523
# Epoch: 10 | Train Loss: 0.50822 | Val Loss: 0.54928
# Epoch: 11 | Train Loss: 0.53060 | Val Loss: 0.45328
# Epoch: 12 | Train Loss: 0.50975 | Val Loss: 0.47101
# Epoch: 13 | Train Loss: 0.50754 | Val Loss: 0.48102
# Epoch: 14 | Train Loss: 0.49711 | Val Loss: 0.44296
# Epoch: 15 | Train Loss: 0.53745 | Val Loss: 0.56511
# Epoch: 16 | Train Loss: 0.50964 | Val Loss: 0.62602
# Epoch: 17 | Train Loss: 0.50178 | Val Loss: 0.47762
# Epoch: 18 | Train Loss: 0.49472 | Val Loss: 0.51301
# Epoch: 19 | Train Loss: 0.48856 | Val Loss: 0.60218
# Epoch: 20 | Train Loss: 0.47471 | Val Loss: 0.49376
# Epoch: 21 | Train Loss: 0.48287 | Val Loss: 0.46566
# Epoch: 22 | Train Loss: 0.47264 | Val Loss: 0.50108
# Epoch: 23 | Train Loss: 0.49374 | Val Loss: 0.53419
# Epoch: 24 | Train Loss: 0.48503 | Val Loss: 0.52690
# Epoch: 25 | Train Loss: 0.47660 | Val Loss: 0.48624
# Epoch: 26 | Train Loss: 0.48130 | Val Loss: 0.51198
# Epoch: 27 | Train Loss: 0.49261 | Val Loss: 0.54079
# Epoch: 28 | Train Loss: 0.47224 | Val Loss: 0.46755
# Epoch: 29 | Train Loss: 0.48231 | Val Loss: 0.63429
# Epoch: 30 | Train Loss: 0.47347 | Val Loss: 0.51827
# Epoch: 31 | Train Loss: 0.47818 | Val Loss: 0.51896
# Epoch: 32 | Train Loss: 0.46350 | Val Loss: 0.56094
# Epoch: 33 | Train Loss: 0.47229 | Val Loss: 0.48859
# Epoch: 34 | Train Loss: 0.47114 | Val Loss: 0.47454
# Epoch: 35 | Train Loss: 0.44683 | Val Loss: 0.43141
# Epoch: 36 | Train Loss: 0.48098 | Val Loss: 0.49229
# Epoch: 37 | Train Loss: 0.46051 | Val Loss: 0.48519
# Epoch: 38 | Train Loss: 0.47587 | Val Loss: 0.55446
# Epoch: 39 | Train Loss: 0.45417 | Val Loss: 0.51440
# Epoch: 40 | Train Loss: 0.45697 | Val Loss: 0.53090
# Epoch: 41 | Train Loss: 0.43562 | Val Loss: 0.47918
# Epoch: 42 | Train Loss: 0.45506 | Val Loss: 0.45176
# Epoch: 43 | Train Loss: 0.46746 | Val Loss: 0.57276
# Epoch: 44 | Train Loss: 0.46598 | Val Loss: 0.46092
# Epoch: 45 | Train Loss: 0.47237 | Val Loss: 0.56244
# Epoch: 46 | Train Loss: 0.46986 | Val Loss: 0.52136
# Epoch: 47 | Train Loss: 0.46701 | Val Loss: 0.54049
# Epoch: 48 | Train Loss: 0.46855 | Val Loss: 0.44096
# Epoch: 49 | Train Loss: 0.45693 | Val Loss: 0.55679
# Epoch: 50 | Train Loss: 0.44287 | Val Loss: 0.48311
# Epoch: 51 | Train Loss: 0.46801 | Val Loss: 0.50939
# Epoch: 52 | Train Loss: 0.45745 | Val Loss: 0.52082
# Epoch: 53 | Train Loss: 0.45738 | Val Loss: 0.51318
# Epoch: 54 | Train Loss: 0.43292 | Val Loss: 0.44581
# Epoch: 55 | Train Loss: 0.47069 | Val Loss: 0.49022
# Epoch: 56 | Train Loss: 0.44578 | Val Loss: 0.48343
# Epoch: 57 | Train Loss: 0.45837 | Val Loss: 0.51571
# Epoch: 58 | Train Loss: 0.43634 | Val Loss: 0.49711
# Epoch: 59 | Train Loss: 0.45539 | Val Loss: 0.52777
# Epoch: 60 | Train Loss: 0.43882 | Val Loss: 0.50773
# Epoch: 61 | Train Loss: 0.45658 | Val Loss: 0.49167
# Epoch: 62 | Train Loss: 0.43628 | Val Loss: 0.45655
# Epoch: 63 | Train Loss: 0.44779 | Val Loss: 0.49049
# Epoch: 64 | Train Loss: 0.45295 | Val Loss: 0.48025
# Epoch: 65 | Train Loss: 0.44364 | Val Loss: 0.49244
# Epoch: 66 | Train Loss: 0.45307 | Val Loss: 0.52941
# Epoch: 67 | Train Loss: 0.44288 | Val Loss: 0.45890
# Epoch: 68 | Train Loss: 0.44705 | Val Loss: 0.47220
# Epoch: 69 | Train Loss: 0.44322 | Val Loss: 0.55040
# Epoch: 70 | Train Loss: 0.44182 | Val Loss: 0.47111
# Epoch: 71 | Train Loss: 0.43423 | Val Loss: 0.51402
# Epoch: 72 | Train Loss: 0.44273 | Val Loss: 0.45326
# Epoch: 73 | Train Loss: 0.44481 | Val Loss: 0.46657
# Epoch: 74 | Train Loss: 0.43398 | Val Loss: 0.49239
# Epoch: 75 | Train Loss: 0.42424 | Val Loss: 0.52237
# Epoch: 76 | Train Loss: 0.41871 | Val Loss: 0.48799
# Epoch: 77 | Train Loss: 0.43691 | Val Loss: 0.51014
# Epoch: 78 | Train Loss: 0.45249 | Val Loss: 0.47112
# Epoch: 79 | Train Loss: 0.43733 | Val Loss: 0.49100
# Epoch: 80 | Train Loss: 0.43991 | Val Loss: 0.45488
# Epoch: 81 | Train Loss: 0.41439 | Val Loss: 0.51822
# Epoch: 82 | Train Loss: 0.42741 | Val Loss: 0.49922
# Epoch: 83 | Train Loss: 0.44649 | Val Loss: 0.50604
# Epoch: 84 | Train Loss: 0.40836 | Val Loss: 0.47925
# Epoch: 85 | Train Loss: 0.43370 | Val Loss: 0.51363
# Epoch: 86 | Train Loss: 0.42455 | Val Loss: 0.43138
# Epoch: 87 | Train Loss: 0.44374 | Val Loss: 0.52884
# Epoch: 88 | Train Loss: 0.41266 | Val Loss: 0.40770
# Epoch: 89 | Train Loss: 0.42631 | Val Loss: 0.45918
# Epoch: 90 | Train Loss: 0.41172 | Val Loss: 0.42634
# Epoch: 91 | Train Loss: 0.40107 | Val Loss: 0.41730
# Epoch: 92 | Train Loss: 0.41722 | Val Loss: 0.45248
# Epoch: 93 | Train Loss: 0.42012 | Val Loss: 0.39935
# Epoch: 94 | Train Loss: 0.41411 | Val Loss: 0.46855
# Epoch: 95 | Train Loss: 0.40036 | Val Loss: 0.42305
# Epoch: 96 | Train Loss: 0.41497 | Val Loss: 0.41037
# Epoch: 97 | Train Loss: 0.41109 | Val Loss: 0.46012
# Epoch: 98 | Train Loss: 0.38055 | Val Loss: 0.54149
# Epoch: 99 | Train Loss: 0.40522 | Val Loss: 0.49776
# Epoch: 100 | Train Loss: 0.38233 | Val Loss: 0.38711
# Epoch: 101 | Train Loss: 0.39696 | Val Loss: 0.45132
# Epoch: 102 | Train Loss: 0.39943 | Val Loss: 0.38307
# Epoch: 103 | Train Loss: 0.38691 | Val Loss: 0.42263
# Epoch: 104 | Train Loss: 0.39634 | Val Loss: 0.40379
# Epoch: 105 | Train Loss: 0.37561 | Val Loss: 0.42571
# Epoch: 106 | Train Loss: 0.36767 | Val Loss: 0.41339
# Epoch: 107 | Train Loss: 0.38669 | Val Loss: 0.44535
# Epoch: 108 | Train Loss: 0.39101 | Val Loss: 0.38475
# Epoch: 109 | Train Loss: 0.38478 | Val Loss: 0.45086
# Epoch: 110 | Train Loss: 0.38713 | Val Loss: 0.44523
# Epoch: 111 | Train Loss: 0.37346 | Val Loss: 0.43767
# Epoch: 112 | Train Loss: 0.37821 | Val Loss: 0.40663
# Epoch: 113 | Train Loss: 0.38454 | Val Loss: 0.40275
# Epoch: 114 | Train Loss: 0.37124 | Val Loss: 0.39515
# Epoch: 115 | Train Loss: 0.37757 | Val Loss: 0.41656
# Epoch: 116 | Train Loss: 0.38475 | Val Loss: 0.40663
# Epoch: 117 | Train Loss: 0.39105 | Val Loss: 0.47306
# Epoch: 118 | Train Loss: 0.36094 | Val Loss: 0.42055
# Epoch: 119 | Train Loss: 0.36138 | Val Loss: 0.39480
# Epoch: 120 | Train Loss: 0.37029 | Val Loss: 0.46928
# Epoch: 121 | Train Loss: 0.36299 | Val Loss: 0.37594
# Epoch: 122 | Train Loss: 0.37173 | Val Loss: 0.41437
# Epoch: 123 | Train Loss: 0.35892 | Val Loss: 0.38185
# Epoch: 124 | Train Loss: 0.35910 | Val Loss: 0.41399
# Epoch: 125 | Train Loss: 0.35775 | Val Loss: 0.42693
# Epoch: 126 | Train Loss: 0.35491 | Val Loss: 0.42501
# Epoch: 127 | Train Loss: 0.35904 | Val Loss: 0.47714
# Epoch: 128 | Train Loss: 0.36139 | Val Loss: 0.38062
# Epoch: 129 | Train Loss: 0.35067 | Val Loss: 0.40320
# Epoch: 130 | Train Loss: 0.35472 | Val Loss: 0.38660
# Epoch: 131 | Train Loss: 0.36551 | Val Loss: 0.43979
# Epoch: 132 | Train Loss: 0.35000 | Val Loss: 0.38790
# Epoch: 133 | Train Loss: 0.34255 | Val Loss: 0.39379
# Epoch: 134 | Train Loss: 0.34135 | Val Loss: 0.44608
# Epoch: 135 | Train Loss: 0.32907 | Val Loss: 0.33761
# Epoch: 136 | Train Loss: 0.35669 | Val Loss: 0.35689
# Epoch: 137 | Train Loss: 0.34702 | Val Loss: 0.40472
# Epoch: 138 | Train Loss: 0.34309 | Val Loss: 0.47923
# Epoch: 139 | Train Loss: 0.36328 | Val Loss: 0.36850
# Epoch: 140 | Train Loss: 0.34924 | Val Loss: 0.33430
# Epoch: 141 | Train Loss: 0.34162 | Val Loss: 0.42505
# Epoch: 142 | Train Loss: 0.34075 | Val Loss: 0.39889
# Epoch: 143 | Train Loss: 0.33951 | Val Loss: 0.36435
# Epoch: 144 | Train Loss: 0.34107 | Val Loss: 0.35975
# Epoch: 145 | Train Loss: 0.34629 | Val Loss: 0.43043
# Epoch: 146 | Train Loss: 0.34546 | Val Loss: 0.38792
# Epoch: 147 | Train Loss: 0.33781 | Val Loss: 0.39675
# Epoch: 148 | Train Loss: 0.34702 | Val Loss: 0.34183
# Epoch: 149 | Train Loss: 0.33225 | Val Loss: 0.36515
# Epoch: 150 | Train Loss: 0.34999 | Val Loss: 0.38292
# Epoch: 151 | Train Loss: 0.33221 | Val Loss: 0.33500
# Epoch: 152 | Train Loss: 0.31009 | Val Loss: 0.32806
# Epoch: 153 | Train Loss: 0.31961 | Val Loss: 0.41997
# Epoch: 154 | Train Loss: 0.32306 | Val Loss: 0.35903
# Epoch: 155 | Train Loss: 0.33602 | Val Loss: 0.31922
# Epoch: 156 | Train Loss: 0.34361 | Val Loss: 0.37498
# Epoch: 157 | Train Loss: 0.33212 | Val Loss: 0.38823
# Epoch: 158 | Train Loss: 0.31653 | Val Loss: 0.41570
# Epoch: 159 | Train Loss: 0.35618 | Val Loss: 0.34688
# Epoch: 160 | Train Loss: 0.31915 | Val Loss: 0.37775
# Epoch: 161 | Train Loss: 0.30421 | Val Loss: 0.42117
# Epoch: 162 | Train Loss: 0.32792 | Val Loss: 0.37283
# Epoch: 163 | Train Loss: 0.31212 | Val Loss: 0.34198
# Epoch: 164 | Train Loss: 0.32840 | Val Loss: 0.32268
# Epoch: 165 | Train Loss: 0.31816 | Val Loss: 0.31453
# Epoch: 166 | Train Loss: 0.32344 | Val Loss: 0.30684
# Epoch: 167 | Train Loss: 0.34008 | Val Loss: 0.32220
# Epoch: 168 | Train Loss: 0.32445 | Val Loss: 0.32809
# Epoch: 169 | Train Loss: 0.33164 | Val Loss: 0.35795
# Epoch: 170 | Train Loss: 0.32196 | Val Loss: 0.33395
# Epoch: 171 | Train Loss: 0.31875 | Val Loss: 0.37519
# Epoch: 172 | Train Loss: 0.33368 | Val Loss: 0.36630
# Epoch: 173 | Train Loss: 0.33581 | Val Loss: 0.34412
# Epoch: 174 | Train Loss: 0.32732 | Val Loss: 0.37562
# Epoch: 175 | Train Loss: 0.32494 | Val Loss: 0.31082
# Epoch: 176 | Train Loss: 0.32008 | Val Loss: 0.35213
# Epoch: 177 | Train Loss: 0.30522 | Val Loss: 0.38969
# Epoch: 178 | Train Loss: 0.30818 | Val Loss: 0.35309
# Epoch: 179 | Train Loss: 0.30420 | Val Loss: 0.35318
# Epoch: 180 | Train Loss: 0.30502 | Val Loss: 0.38458
# Epoch: 181 | Train Loss: 0.32060 | Val Loss: 0.29952
# Epoch: 182 | Train Loss: 0.31117 | Val Loss: 0.33753
# Epoch: 183 | Train Loss: 0.33150 | Val Loss: 0.38098
# Epoch: 184 | Train Loss: 0.30867 | Val Loss: 0.32903
# Epoch: 185 | Train Loss: 0.29805 | Val Loss: 0.27944
# Epoch: 186 | Train Loss: 0.31053 | Val Loss: 0.37719
# Epoch: 187 | Train Loss: 0.31808 | Val Loss: 0.30514
# Epoch: 188 | Train Loss: 0.32573 | Val Loss: 0.36034
# Epoch: 189 | Train Loss: 0.31446 | Val Loss: 0.33131
# Epoch: 190 | Train Loss: 0.30857 | Val Loss: 0.37487
# Epoch: 191 | Train Loss: 0.31458 | Val Loss: 0.35056
# Epoch: 192 | Train Loss: 0.30377 | Val Loss: 0.35335
# Epoch: 193 | Train Loss: 0.31054 | Val Loss: 0.38753
# Epoch: 194 | Train Loss: 0.31367 | Val Loss: 0.31880
# Epoch: 195 | Train Loss: 0.30831 | Val Loss: 0.34926
# Epoch: 196 | Train Loss: 0.31139 | Val Loss: 0.31315
# Epoch: 197 | Train Loss: 0.30290 | Val Loss: 0.38049
# Epoch: 198 | Train Loss: 0.31726 | Val Loss: 0.35470
# Epoch: 199 | Train Loss: 0.28739 | Val Loss: 0.34379

# %%
losses_arr = np.array(metrics['losses'])
val_losses_arr = np.array(metrics['val_losses'])
losses_arr.shape
fig, ax = plt.subplots(1,sharex=True, figsize=(15, 8))
ax.plot(losses_arr[:,0], 'C3o-', label = "Total Train loss")
ax.plot(val_losses_arr[:,0], 'C0o-', label = "Total Val loss")
ax.set(ylabel='Loss')
ax.grid()

plt.tight_layout()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 43.0, 'Epochs')

# %%
# Evaluate points with trained model
model.eval()
y_preds = []
for x in testloader:
    x = x[0].to(device)
    evals = model(x.unsqueeze(-1)).squeeze()
    for k in evals:
        y_preds.append(k.detach().to("cpu").numpy())

len(y_preds)
# Out:
# 500

# %%
plt.plot(x_test,y_test,'C3o')
plt.plot(x_test,y_preds)
plt.title("Test data")
# Out:
# Text(0.5, 1.0, 'Test data')
